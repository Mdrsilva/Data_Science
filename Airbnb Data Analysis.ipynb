# %% [markdown]
# <a href="https://colab.research.google.com/github/Mdrsilva/Data_Science/blob/main/Airbnb%20Data%20Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <img alt="Colaboratory logo" width="7%" src="https://raw.githubusercontent.com/carlosfab/escola-data-science/master/img/novo_logo_bg_claro.png">
#
# #### **Data Science and Data Analysis**
# *by [Marriane Silva](https://github.com/Mdrsilva)*
#
# ---
#
# # Airbnb Data Analysis - *Vancouver, BC - Canada*
#
#
# The [Airbnb](https://www.airbnb.com/) began in 2008 when two designers who had space to share hosted three travelers looking for a place to stay. Nowadays it is considered the **biggest hotel company**, and the interesting fact is that it **does not own any hotel**!
#
# Connecting travelers and hosts that want to rent their places in a practice way, the Airbnb platform helps make sharing easy, enjoyable, and safe.
#
#
# Online marketplace for lodging, primarily homestays for vacation rentals, and tourism activities, in the beginning of 2022, guests have booked over 1 billion stays all over the world, according to [Airbnb Statistics](https://ipropertymanagement.com/research/airbnb-statistics).
#
#
# Airbnb makes data available for some of the main cities in the world. That can be found in the [Inside Airbnb Portal](http://insideairbnb.com/get-the-data.html), where it is viable to have a big ammount of data to develop projects and *Data Science* solutions.
# <center><img alt="Analysing Airbnb" width="10%" src="https://www.area360.com.au/wp-content/uploads/2017/09/airbnb-logo.jpg"></center>
#
# **In this *notebook*, I analyze the data from Vancouver city in Canada, and extract some insights from the raw data.**

# %% [markdown]
# #Vancouver Overview
#
#
# Located in the Lower Mainland region of British Columbia, in Canada, Vancouver is
# Buenos Aires é a capital e maior cidade da Argentina, além de ser a segunda maior área metropolitana da América do Sul, depois da Grande São Paulo. Ela está localizada na costa ocidental do estuário do Rio da Prata, na costa sudeste do continente. A conurbação da Grande Buenos Aires, que também inclui vários distritos da província de Buenos Aires, constitui a terceira maior aglomeração urbana da América Latina, com uma população de cerca de 13 milhões de pessoas.
#
# A cidade de Buenos Aires não é parte da província de Buenos Aires e nem é a sua capital, mas um distrito autônomo.[4] Em 1880, depois de décadas de luta política, Buenos Aires foi federalizada e separada da província de Buenos Aires.Os limites da cidade foram ampliados para incluir as cidades de Belgrano e Flores, ambas agora bairros da cidade. A emenda constitucional de 1994 concedeu a autonomia política à cidade, daí o seu nome formal: Ciudad Autónoma de Buenos Aires (em português: Cidade Autônoma de Buenos Aires). Seus cidadãos elegeram pela primeira vez um chefe de governo (ou seja, o prefeito) em 1996. Antes, o prefeito era diretamente nomeado pelo Presidente da República.
#
# <center><img alt="Analysing Airbnb" width="80%" src="https://www.chicdarling.com/wp-content/uploads/2015/12/bigstock-Science-World-In-Vancouver-Ca-93393425.jpg"></center>
#
# Por algumas formas de comparação, Buenos Aires é uma das 20 maiores cidades do mundo. Ao lado de São Paulo e Cidade do México, é Buenos Aires uma das três únicas cidades latino-americanas consideradas uma cidade global alfa.A Argentina tem a terceira melhor qualidade de vida na América Latina. A qualidade de vida na cidade de Buenos Aires é classificada como sendo a 62.ª melhor do mundo.A capital argentina é uma das mais importantes e mais populosas entre as capitais sul-americanas, muitas vezes referida como a Paris da América do Sul.
#
# Buenos Aires é um dos mais importantes destinos turísticos do mundo, é conhecida por sua arquitetura de estilo europeu e por sua rica vida cultural, com a maior concentração de teatros do mundo. Buenos Aires também sediou os Jogos Olímpicos de Verão da Juventude de 2018. As pessoas nascidas em Buenos Aires são referidas como portenhos (pessoas do porto). A cidade é a terra natal do atual papa, Francisco (ex-arcebispo de Buenos Aires), e de Máxima dos Países Baixos, a atual rainha-consorte da realeza neerlandesa.

# %% [markdown]
# ## Data Extractions
#
# The data was obtained at [Inside Airbnb](http://insideairbnb.com/get-the-data.html) and it is composed of 1 table, **_listings.csv_**, which summaryze information and metrics for listings in Vancouver.

# %% [markdown]
# Before moving further, let's import the table and do some basic visualizations.

# %%
# Let's import all the required libraries needed for this analysis

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
# import the required file
df = pd.read_csv("http://data.insideairbnb.com/canada/bc/vancouver/2022-09-10/visualisations/listings.csv")
df.head()
# Out:
#       id                                               name  host_id  \
# 0  13358  Monthly (or Longer ) Designer One Bedroom Down...    52116
# 1  13490                       Vancouver's best kept secret    52467
# 2  14267                                  EcoLoft Vancouver    56030
# 3  14424    Spacious one-bedroom in sought-after Strathcona    56709
# 4  16254      Close to PNE/Hastings Park Garden level suite    63238
#
#         host_name  neighbourhood_group             neighbourhood  latitude  \
# 0            Lynn                  NaN                  West End  49.28201
# 1            Iris                  NaN  Kensington-Cedar Cottage  49.25622
# 2  Peter & Alison                  NaN  Kensington-Cedar Cottage  49.24922
# 3     Samantha Jo                  NaN         Downtown Eastside  49.27921
# 4           Jason                  NaN          Hastings-Sunrise  49.27721
#
#    longitude        room_type  price  minimum_nights  number_of_reviews  \
# ...

# %% [markdown]
# ## Análise dos Dados
# #Data Descriptions
#
# In this analysis, I investigate some features that are associated with the XXXXXXXXXXcheese fat level. Our problem is to predict the fat level of each example (lower or higher).
#
# Question(s) of interests
# In this analysis, I investigate a number of questions associated with the collection of Disney Movies datasets. In part, I am interested in finding out which are the highest grossing Disney movies. The motivation for this is to compare a general study related to Movie genres ranked by total box office revenue in North America 1995-2021, which can be find here. This study found Adventure, Action, Drama, comedy and Thriller/Suspense were in the top 5 of total box office revenue in the period of 1995 to 2021. I am also interested to find out, after know the top 5 of Disney Movie, wheather there is a trend to released them along the years 1937 to 2016.
#
# Dataset description
# The below descriptions were taken directly from the website where the datasets were obtained.
#
# The listings dataset contains information of id, name, host_id, host_name, neighbourhood_group, neighbourhood, latitude, longitude, room_type, price, minimum_nights, number_of_reviews, last_review, reviews_per_month, calculated_host_listings_count, availability_365, number_of_reviews_ltm, license.
#
# id	name	host_id	host_name	neighbourhood_group	neighbourhood	latitude	longitude	room_type	price	minimum_nights	number_of_reviews	last_review	reviews_per_month	calculated_host_listings_count	availability_365	number_of_reviews_ltm	license
#
#
# movie title, release date, genre, mpaa rating, total gross and inflation adjusted gross.
# disney-characters.csv
# This file contains information of movie title, release date, hero, villian and song.
# disney-director.csv
# This file includes information of the movie and its director.
# id	name	host_id	host_name	neighbourhood_group	neighbourhood	latitude	longitude	room_type	price	minimum_nights	number_of_reviews	last_review	reviews_per_month	calculated_host_listings_count	availability_365	number_of_reviews_ltm	license

# %% [markdown]
# **Variables dictionary**
# * `id` - Airbnb's unique identifier for the listing
# *  `name`	- Name of the listing
# * `host_id`	-	Airbnb's unique identifier for the host/user
# * `host_name`	-	Name of the host. Usually just the first name(s).
# * `neighbourhood_cleansed`	-	The neighbourhood as geocoded using the latitude and longitude against neighborhoods as defined by open or public digital shapefiles.
# * `neighbourhood`	- Neighbourhood name
# * `latitude`	-	Uses the World Geodetic System (WGS84) projection for latitude and longitude.
# * `longitude`	- Uses the World Geodetic System (WGS84) projection for latitude and longitude.
# * `room_type`	-	Entire home/apt, Private room, Shared room, Hotel
# * `price`	-	Daily price in local currency
# * `minimum_nights`	-	Minimum number of night stay for the listing (calendar rules may be different)
# * `number_of_reviews`	- The number of reviews the listing has
# * `last_review`	- The date of the last/newest review
# * `reviews_per_month` -	The number of reviews the listing has over the lifetime of the listing
# * `calculated_host_listings_count`	-	The number of listings the host has in the current scrape, in the city/region geography.	The number of listings the host has in the current scrape, in the city/region geography.
# * `availability_365` - avaliability_x. The availability of the listing x days in the future as determined by the calendar. Note a listing may not be available because it has been booked by a guest or blocked by the host.
# * `number_of_reviews_ltm`	-The number of reviews the listing has (in the last 12 months)
# * `license`	- The licence/permit/registration number
#
# Let's see how the table looks.

# %%
# Check the first 5 entries of the dataset
df.head()
# Out:
#       id  ...    license
# 0  10080  ...  18-476608
# 1  13188  ...  20-160253
# 2  13358  ...  18-611603
# 3  13490  ...        NaN
# 4  14267  ...  21-156500
#
# [5 rows x 18 columns]

# %% [markdown]
# ### **Q1. How many attributes (variables) and how many entries does our dataset have? What types of variables?**

# %% [markdown]
# Let's go ahead and identify how many entries our dataset has and see the types of each column.
#
# This *dataset* we downloaded is the summarized version of Airbnb. On the same page there is a full version with more than 74 variables.

# %%
# Identify the DataFrame data volume
print("Entries:\t{}".format(df.shape[0]))
print("Variables:\t{}".format(df.shape[1]))
# Check the first 5 entries of the dataset
display(df.dtypes)
# Out:
# Entries:	4531
# Variables:	18
# id                                  int64
# name                               object
# host_id                             int64
# host_name                          object
# neighbourhood_group               float64
# neighbourhood                      object
# latitude                          float64
# longitude                         float64
# room_type                          object
# price                               int64
# minimum_nights                      int64
# number_of_reviews                   int64
# last_review                        object
# reviews_per_month                 float64
# calculated_host_listings_count      int64
# availability_365                    int64
# number_of_reviews_ltm               int64
# license                            object
# dtype: object

# %% [markdown]
# The df table has 23828 rows and 16 columns and the columns price is of a type integer, and latitude and longitude are of type float. In this case, it is the type I want to and do not need to convert this columns datatype.

# %% [markdown]
# ### **Q2. What is the percentage of missing values in the *dataset*?**
#
# The quality of a dataset is related to the number of missing values. It is crucial to understand whether these null values are significant compared to the total entries.
#
# That being said, before I start my analysis, it is important to be able to deal with messy data, whether that means missing values, inconsistent formatting, malformed records, or nonsensical outliers.
#
# * You can see that the `neighbourhood_group` column has 100% of its values missing. As a result, I will not include this column in my analysis.
# * The `reviews_per_month` and `last_review` variables have null values in almost 17% of the rows. In the other hand, `license` column has about 30% null values.
# * The `host_name` variable has approximately 0.02% null values.

# %%
# ordenar em ordem decrescente as variáveis por seus valores ausentes
(df.isnull().sum()/df.shape[0]).sort_values(ascending=False)
# Out:
# neighbourhood_group               1.000000
# license                           0.297285
# reviews_per_month                 0.165306
# last_review                       0.165306
# host_name                         0.000221
# minimum_nights                    0.000000
# number_of_reviews_ltm             0.000000
# availability_365                  0.000000
# calculated_host_listings_count    0.000000
# number_of_reviews                 0.000000
# id                                0.000000
# name                              0.000000
# room_type                         0.000000
# longitude                         0.000000
# latitude                          0.000000
# neighbourhood                     0.000000
# host_id                           0.000000
# price                             0.000000
# dtype: float64

# %% [markdown]
# The columns neighbourhood_group and license have lower predictive power and considered ammount of missing values. Let's drop those 2 columns from my dataset.

# %%
# Excluding neighbourhood_group and license columns
df.drop(columns=['neighbourhood_group', 'license'], inplace=True)
# Out:
# id                                  0
# name                                0
# host_id                             0
# host_name                           1
# neighbourhood                       0
# latitude                            0
# longitude                           0
# room_type                           0
# price                               0
# minimum_nights                      0
# number_of_reviews                   0
# last_review                       749
# reviews_per_month                 749
# calculated_host_listings_count      0
# availability_365                    0
# number_of_reviews_ltm               0
# dtype: int64

# %% [markdown]
# ### **Q3. What is the type of distribution of the variables?**
# In order to verify the variables distribuitions, I am plotting a histogram of the numeric variables.

# %%
# Plot the histogram of numeric variables
df.hist(bins=15, figsize=(15,20));


### Write down conclusions about those histograms. watch Rafael class about null values

# %% [markdown]
# ### **Q4. Qual a média dos preços de aluguel?**

# %%
# ver a média da coluna `price``
df.price.mean()
# Out:
# 178.96799823438533

# %% [markdown]
# ### **Q5. Are there outliers?** ###
#
# Pela distribuição do histograma, é possível verificar indícios da presença de outliers (*Outliers* são pontos discrepantes, que estão destoando do padrão do conjunto de dados). Olhe por exemplo as variáveis price, minimum_nights e calculated_host_listings_count.
#
# É muito importante conseguir identificar e tratar esses outliers, pois eles podem nos mostrar uma imagem incorreta dos nossos dados.
#
# Os valores não seguem uma distruição, e distorcem toda a representação gráfica.
#
# Para confirmar, há duas maneiras rápidas que auxiliam a detecção de outliers. São elas:
# Podemos identificar um outlier de diversas formas, entre elas podemos citar:
#
# * IQR Score
# * Boxplots
#
# Resumo estatístico por meio do método describe()
# Plotar boxplots para a variável.
#
# https://www.simplypsychology.org/boxplot-outliers.png

# %%
#Ver o resumo estatístico das variáveis numéricas

df[['price', 'minimum_nights', 'number_of_reviews', 'reviews_per_month',
    'calculated_host_listings_count', 'availability_365']].describe().round(1)
# Out:
#         price  minimum_nights  ...  calculated_host_listings_count  availability_365
# count  4531.0          4531.0  ...                          4531.0            4531.0
# mean    179.0            18.2  ...                             5.3             127.0
# std     290.7            33.0  ...                            12.0             120.9
# min      13.0             1.0  ...                             1.0               0.0
# 25%      92.5             2.0  ...                             1.0               7.0
# 50%     129.0             4.0  ...                             1.0              88.0
# 75%     199.0            30.0  ...                             3.0             223.0
# max    9999.0           399.0  ...                            77.0             365.0
#
# [8 rows x 6 columns]

# %% [markdown]
# Olhando o resumo estatístico acima, podemos confirmar algumas hipóteses como:
#
# A variável price possui 75% dos valores abaixo de 199.00 CAD, porem seu valor máximo é 9999.00 CAD. That is evident of presence of outliers on this variable.
# A quantidade mínima de noites (minimum_nigts) is 1 night, but the max value is 399 days (over a year), which shows us there are outliers in the minimum_night column as well.

# %% [markdown]
# ## Limpando Outliers
#
# Para tratar dos outliers desse conjunto de dados, iremos analisar a distribuição estatística, plotar boxplots e calcular os limites utilizando a regra do IQR Score.
#
# Primeiramente, vamos lembrar o que é o IQR.
#
# O IQR é calculado subtraindo o Terceiro Quartil (75%) pelo Primeiro Quartil (25%).
#
# # IQR = Q3 - Q1
#
# Vamos dar uma olhada nos nossos dados e ver o que identificamos.
#
# <p align="center"><img src="https://www.simplypsychology.org/boxplot-outliers.png", width="50%"></p>

# %%
# identificando os outliers para a variável price
q1_price = df.price.quantile(.25)
q3_price = df.price.quantile(.75)
IQR_price = q3_price - q1_price
print('Price IQR', IQR_price)

# definindo os limites                                       
sup_price = q3_price + 1.5 * IQR_price
inf_price = q1_price - 1.5 * IQR_price

print('Limite superior de price: ', sup_price)
print('Limite inferior de price: ', inf_price)
# Out:
# Price IQR 106.5
# Limite superior de price:  358.75
# Limite inferior de price:  -67.25

# %% [markdown]
# Aqui podemos ver que, apesar de não termos outliers na parte inferior, as the minimum price in the dataset is 13 CAD. However, I am going to exclude the outliers in the limite superior, which represent 6.4% of the data, as we can see below.

# %%
# verificando o conjunto original
fig, ax = plt.subplots(figsize=(15,3))
df.price.plot(kind='box', vert=False);
ax.set_title('Original Dataset - price')
plt.show()
print("O dataset possui {} colunas".format(df.shape[0]))
print("{} Entradas acima de 358,75".format(len(df[df.price > sup_price])))
print("Representam {:.2f}% do dataset".format((len(df[df.price > sup_price]) / df.shape[0])*100))
# Out:
# O dataset possui 4531 colunas
# 292 Entradas acima de 358,75
# Representam 6.44% do dataset

# %%
# identificando os outliers para a variável minimum_nights
q1_minimum_nights = df.minimum_nights.quantile(.25)
q3_minimum_nights = df.minimum_nights.quantile(.75)
IQR_minimum_nights = q3_minimum_nights - q1_minimum_nights
print('Mininum nights IQR: ', IQR_minimum_nights)

# definindo os limites                                       
sup_minimum_nights = q3_minimum_nights + 1.5 * IQR_minimum_nights
inf_minimum_nights = q1_minimum_nights - 1.5 * IQR_minimum_nights

print('Limite superior de minimum_nights: ', sup_minimum_nights)
print('Limite inferior de minimum_nights: ', inf_minimum_nights)
# Out:
# Mininum nights IQR:  28.0
# Limite superior de minimum_nights:  72.0
# Limite inferior de minimum_nights:  -40.0

# %% [markdown]
# Aqui podemos ver que, apesar de não termos outliers na parte inferior, as minimum night is 1 night CAD. However, I am going to exclude the outliers in the limite superior, which represent 6.4% of the data, as we can see below.

# %%
# verificando o conjunto original
fig, ax = plt.subplots(figsize=(15,3))
df.minimum_nights.plot(kind='box', vert=False);
ax.set_title('Dataset Original - minimum_nights')
plt.show()
print("O dataset possui {} colunas".format(df.shape[0]))
print("{} Entradas acima de 72 minimum nights".format(len(df[df.minimum_nights > sup_minimum_nights])))
print("Representam {:.2f}% do dataset".format((len(df[df.minimum_nights > sup_minimum_nights]) / df.shape[0])*100))
# Out:
# O dataset possui 4531 colunas
# 164 Entradas acima de 72 minimum nights
# Representam 3.62% do dataset

# %%
# limpando o dataset
df_clean = df.copy()

df_clean.drop(df_clean[df_clean.price > sup_price].index, axis=0, inplace=True)
df_clean.drop(df_clean[df_clean.minimum_nights > sup_minimum_nights].index, axis=0, inplace=True)

print('Shape antes da limpeza: ', df.shape)
print('Shape após a limpeza: ',df_clean.shape)
# Out:
# Shape antes da limpeza:  (4531, 16)
# Shape após a limpeza:  (4085, 16)

# %%
# verificando o conjunto limpo
fig, ax = plt.subplots(figsize=(15,3))
df_clean.price.plot(kind='box', vert=False);
ax.set_title('Dataset Limpo - price')
plt.show()
print("Tamanho original: {} colunas".format(df.shape[0]))
print("Tamanho atual: {} colunas".format(df_clean.shape[0]))
# Out:
# Tamanho original: 4531 colunas
# Tamanho atual: 4085 colunas

# %%
# verificando o conjunto limpo
fig, ax = plt.subplots(figsize=(15,3))
df_clean.minimum_nights.plot(kind='box', vert=False);
ax.set_title('Dataset Limpo - minimum nights')
plt.show()
print("Tamanho original: {} colunas".format(df.shape[0]))
print("Tamanho atual: {} colunas".format(df_clean.shape[0]))
# Out:
# Tamanho original: 4531 colunas
# Tamanho atual: 4085 colunas

# %% [markdown]
# Let's check the distribution after the outliers exclusion to ensure there is no outliers that will impact my analysis.

# %%
# verificando as distribuições
df_clean.hist(figsize=(20,15), grid=False);

# %% [markdown]
# ### Conclusions

# %% [markdown]
# ### **Q4. What is the correlation between the variables**
#
#
# Correlation means that there is a relationship between two things. We are looking for a relationship or similarity between two variables in our context.
#
# This relationship can be measured, and it is a function of the correlation coefficient to establish its intensity. To identify the existing correlations between the variables of interest, I will:
#
# Create a correlation matrix
# Generate a heatmap from this array, using the seaborn library.

# %%
# Create matrix corelation
corr = df_clean[['price', 'minimum_nights', 'number_of_reviews', 'reviews_per_month',
    'calculated_host_listings_count', 'availability_365']].corr()


# Display matrix corelation
display(corr)
# Out:
#                                    price  ...  availability_365
# price                           1.000000  ...          0.112816
# minimum_nights                 -0.150187  ...          0.163735
# number_of_reviews              -0.038362  ...          0.015551
# reviews_per_month               0.030518  ...          0.069295
# calculated_host_listings_count -0.066552  ...          0.013674
# availability_365                0.112816  ...          1.000000
#
# [6 rows x 6 columns]

# %%
# plotar um heatmap a partir das correlações
sns.heatmap(corr, cmap = 'RdBu', fmt='.2f', square = True , linecolor='white', annot= True);

# %% [markdown]
# ### **Q6. What type of property is most rented on Airbnb?**
#
# The `room_type` variable column indicates the type of rental that is advertised on Airbnb. If you have already rented on the site, you know that there are options for apartments/whole houses, just renting a room or even sharing a room with other people.
#
# Let's count the number of occurrences of each rental type, using the `value_counts()` method.

# %%
# mostrar a quantidade de cada tipo de imóvel disponível
df_clean.room_type.value_counts()
# Out:
# Entire home/apt    3241
# Private room        830
# Shared room           9
# Hotel room            5
# Name: room_type, dtype: int64

# %%
# mostrar a porcentagem de cada tipo de imóvel disponível
df_clean.room_type.value_counts()/df_clean.shape[0]
# Out:
# Entire home/apt    0.793390
# Private room       0.203182
# Shared room        0.002203
# Hotel room         0.001224
# Name: room_type, dtype: float64

# %% [markdown]
# ### **Q6. What is the most expensive location in Vancouver?**
#
# > Indented block
# One way to check one variable against another is to use `groupby()`. In this case, I want to compare the neighbourhoods based on the rental price.

# %%
# Let's check the average of price per neighbourhood, showing the 10 most expensive Airbnb rents in Vancouver
df_clean.groupby(['neighbourhood']).price.mean().sort_values(ascending=False)[:10]
# Out:
# neighbourhood
# West Point Grey       171.000000
# Downtown Eastside     163.768116
# Downtown              162.753171
# Strathcona            161.111111
# Kitsilano             158.579618
# Fairview              146.758333
# West End              139.751861
# Dunbar Southlands     139.571429
# Shaughnessy           137.893939
# Grandview-Woodland    137.368159
# Name: price, dtype: float64

# %% [markdown]
# As Latitudes and Longitudes are provided for properties, it is possible to plot each point. For this, consider x = longitude and y = latitude.

# %%
# plotar os imóveis pela latitude-longitude
df_clean.plot(kind="scatter", x="longitude", y="latitude", alpha=0.4, c=df_clean['price'], s=8, cmap=plt.get_cmap('jet'), figsize=(15,5));

# %% [markdown]
# ### **What are the average minimum rental nights (minimum_nights)?**

# %%
# ver a média da coluna `minimum_nights`

df_clean.minimum_nights.mean()
# Out:
# 13.62594859241126

# %% [markdown]
# We note that the average number of nights the guest usually rent for rooms in Buenos Aires is approximately 14 nights.

# %% [markdown]
# ## Conclusões

# %% [markdown]
# ## Resources used
# * [Hands-on Data Science by Sigmoidal](https://sigmoidal.ai/)
#     * This course is based on Data Science Projects and Portifolio. As you go through the course, you learn key data science concepts and observe how a data scientist works while building a project of your own.
# * [Programming in Python for Data Science - UBC](https://prog-learn.mds.ubc.ca/en)
#     * This course is part of the Key Capabilities in Data Science Program.
# * [Data Source](http://insideairbnb.com/get-the-data.html)
#     * This Disney Character Success database used in this work was curated by **Kelly Garrett**.
# * [Data Visualization](https://altair-viz.github.io/)
#     * Inspiration for generating the plotting the **Number of Movies Released per Year**.
# * [Question of Interest](https://www.statista.com/statistics/188658/movie-genres-in-north-america-by-box-office-revenue-since-1995)
#     * The question of interest was inspired by searching the website [www.statista.com](https://www.statista.com/statistics/188658/movie-genres-in-north-america-by-box-office-revenue-since-1995) regarding the movie genres in North America by box office revenue since 1995.
# * [Film Rating System](https://en.wikipedia.org/wiki/Motion_Picture_Association_film_rating_system)
#     * The Motion Picture Association (MPA) film rating system is used in the United States and its territories to rate a motion picture's suitability for certain audiences based on its content. known as the Motion Picture Association of America (MPAA) from 1945–2019.
# * [Python Code Resources](https://www.python.org/dev/peps/pep-0008)
#
# * [Most popular movie genres in North America from 1995 to 2021, by total box office revenue](https://www.statista.com/statistics/188658/movie-genres-in-north-america-by-box-office-revenue-since-1995)
# * [Airbnb Statistics](https://ipropertymanagement.com/research/airbnb-statistics)
# * [Festival and Events in Vancouver](https://curiocity.com/vancouver/)
# * [Missing values](https://www.geeksforgeeks.org/working-with-missing-data-in-pandas/)
